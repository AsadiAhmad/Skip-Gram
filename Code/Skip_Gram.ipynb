# %% [markdown]
# <a href="https://colab.research.google.com/github/AsadiAhmad/Skip-Gram/blob/main/Code/Skip_Gram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1: Import Libraries

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)

# %%
from typing import List

import requests

import numpy as np
from numpy.linalg import norm
import polars as pl

from collections import Counter
from gensim.models import Word2Vec

import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2: Download Documents and Queries

# %%
def download_text(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch {url}. Status code: {response.status_code}")
        return None

# %%
urls = {
    "Documents": "https://raw.githubusercontent.com/AsadiAhmad/Skip-Gram/main/Dataset/Documents.txt",
    "Queries": "https://raw.githubusercontent.com/AsadiAhmad/Skip-Gram/main/Dataset/Queries.txt",
    "Result": "https://raw.githubusercontent.com/AsadiAhmad/Skip-Gram/main/Dataset/Result.txt"
}

# %%
data = {}
for key, url in urls.items():
    data[key] = download_text(url)

print("Datasets downloaded successfully!")
# Out:
# Datasets downloaded successfully!

# %% [markdown]
# # Step 3: Convert Dataset into Polars Data frame

# %% [markdown]
# ## Convert into polars

# %%
documents_text = data["Documents"]
queries_text = data["Queries"]
result_text = data["Result"]

# %%
documents_splited = documents_text.split('********************************************')

for index, doc in enumerate(documents_splited):
    documents_splited[index] = doc.strip()

documents = pl.DataFrame({
    "index": range(1, len(documents_splited) + 1),
    "text": documents_splited
})

documents = documents.with_columns(
    pl.col("text")
    .str.split("\n")
    .list.slice(1)
    .list.join(" ")
    .str.replace_all(r'\s+', ' ')
    .str.strip_chars()
)

# %%
queries_splited = [doc.strip() for doc in queries_text.split('#') if doc.strip()]

queries = pl.DataFrame({
    "index": range(1, len(queries_splited) + 1),
    "text": queries_splited
})

queries = queries.with_columns(
    pl.col("text")
    .str.split("\n")
    .list.slice(1)
    .list.join(" ")
    .str.replace_all(r'\s+', ' ')
    .str.strip_chars()
)

# %%
reference_lines = []
for line in result_text.split('\n'):
    line = line.strip()
    if line.endswith('-1'):
        refs = line[:-2].strip().split()
        reference_lines.append([int(ref) for ref in refs])

real_result = pl.DataFrame({
    "index": range(1, len(reference_lines) + 1),
    "references": reference_lines
})

# %% [markdown]
# ## Set Config for polar showing

# %%
pl.Config.set_tbl_rows(-1)
pl.Config.set_tbl_cols(-1)
pl.Config.set_fmt_str_lengths(70)
pl.Config.set_fmt_table_cell_list_len(10)
# Out:
# polars.config.Config

# %% [markdown]
# ## Showing all frames

# %%
print(documents.row(0, named=True))
# Out:
# {'index': 1, 'text': 'THE INDIAN COUNCIL OF LIBRARY AND INFORMATION SERVICES RESEARCH AND TRAINING: A PROPOSAL FOR CONSIDERATION. CRITICALLY EXAMINES THE INDIAN LIBRARY SCENE. THE MANAGEMENT, OPERATION, AND SERVICES OF MOST LIBRARIES IS INEFFICIENT AND INEFFECTIVE, RESULTING IN GRAVE MISALLOCATION AND UNDERUTILISATION OF LIBRARY RESOURCES. LITTLE MAJOR RESEARCH HAS BEEN CARRIED OUT. UNIVERSITY LIBRARIANSHIP COURSES ARE NOT MUCH HELP FOR MANAGING AND OPERATING LIBRARIES EFFICIENTLY. THE MAJOR NATIONAL INSTITUTIONS HAVE SERIOUS LIMITATIONS. TO IMPROVE THE SITUATION, PROPOSES THE ESTABLISHMENT OF AN INDIAN COUNCIL OF LIBRARY AND INFORMATION SERVICES RESEARCH AND TRAINING. THE COUNCIL WOULD BE SET UP BY THE GOVERNMENT AND HAVE WELL-DEFINED ROLES AND FUNCTIONS COVERING ALL ASPECTS OF INDIAN LIBRARIANSHIP.'}

# %%
documents.head(10)
# Out:
# shape: (10, 2)
# ┌───────┬─────────────────────────────────────────────────────────────────────────┐
# │ index ┆ text                                                                    │
# │ ---   ┆ ---                                                                     │
# │ i64   ┆ str                                                                     │
# ╞═══════╪═════════════════════════════════════════════════════════════════════════╡
# │ 1     ┆ THE INDIAN COUNCIL OF LIBRARY AND INFORMATION SERVICES RESEARCH AND TR… │
# │ 2     ┆ THE LINGERING FRAGRANCE: PROCEEDINGS OF THE XXIV ALL INDIA LIBRARY CON… │
# │ 3     ┆ XXV ALL INDIA LIBRARY CONFERENCE TRIVANDRUM 14-18 MAY 1979. PAPERS AND… │
# │ 4     ┆ MALAWI LIBRARY ASSOCIATION SECOND ANNUAL GENERAL MEETING, CHANCELLOR C… │
# │ 5     ┆ A PERSONAL VIEW OF THE ZAMBIA LIBRARY SERVICE. PERSONAL VIEW OF THE SE… │
# │ 6     ┆ CLA 80: TURNING ON THE POWER. REPORT OF PROCEEDINGS OF THE 35TH ANNUAL… │
# │ 7     ┆ UNCERTAIN BEGINNINGS. REPORT OF THE AMERICAN LIBRARY ASSOCIATION MIDWI… │
# │ 8     ┆ MIDWINTER IN REAGAN'S WASHINGTON: AN ALA CONFERENCE REPORT. REPORT OF … │
# │ 9     ┆ THE WHITE HOUSE CONFERENCE ON LIBRARY AND INFORMATION SERVICES, 1979. … │
# │ 10    ┆ INFORMATION: BOOKS ARE JUST THE BEGINNING. THE MICHIGAN WHITE HOUSE CO… │
# └───────┴─────────────────────────────────────────────────────────────────────────┘

# %%
queries.head(10)
# Out:
# shape: (10, 2)
# ┌───────┬─────────────────────────────────────────────────────────────────────────┐
# │ index ┆ text                                                                    │
# │ ---   ┆ ---                                                                     │
# │ i64   ┆ str                                                                     │
# ╞═══════╪═════════════════════════════════════════════════════════════════════════╡
# │ 1     ┆ I AM INTERESTED IN THE IDENTIFICATION AND EVALUATION OF NOVEL COMPUTER… │
# │ 2     ┆ I WOULD BE INTERESTED TO RECEIVE INFORMATION ON NON-USERS OF LIBRARIES… │
# │ 3     ┆ I AM INTERESTED IN COMPUTER DOCUMENTATION SYSTEMS FOR CHEMICAL PATENTS… │
# │ 4     ┆ I WOULD BE PLEASED TO RECEIVE ANY INFORMATION ON THE USE OF JOURNALS I… │
# │ 5     ┆ MY DISSERTATION IS AN OVERVIEW OF NEWS DATABASES, LOOKING AT THE AVAIL… │
# │ 6     ┆ MY DISSERTATION IS ON LIBRARY OUTREACH FOR THE CHINESE COMMUNITY IN SH… │
# │ 7     ┆ I WOULD BE PLEASED TO RECEIVE PAPERS ON THE SECURITY OF INFORMATION IN… │
# │ 8     ┆ I AM INTERESTED IN THE PROFESSIONAL EDUCATION OF LIBRARIANS, IN PARTIC… │
# │ 9     ┆ I AM INTERESTED IN THE EXTENT TO WHICH LIBRARIES ARE CHARGING FOR SERV… │
# │ 10    ┆ I AM INTERESTED IN INFORMATION ON THE PROVISION OF CURRENT AWARENESS B… │
# └───────┴─────────────────────────────────────────────────────────────────────────┘

# %%
real_result.head(10)
# Out:
# shape: (10, 2)
# ┌───────┬──────────────────────────────────────────────────────────────┐
# │ index ┆ references                                                   │
# │ ---   ┆ ---                                                          │
# │ i64   ┆ list[i64]                                                    │
# ╞═══════╪══════════════════════════════════════════════════════════════╡
# │ 1     ┆ [3392, 3396]                                                 │
# │ 2     ┆ [2623, 4291]                                                 │
# │ 3     ┆ [1407, 1431, 3794, 3795, 3796]                               │
# │ 4     ┆ [604, 3527, 4644, 5087, 5112, 5113, 5295]                    │
# │ 5     ┆ [3401]                                                       │
# │ 6     ┆ [111, 112, 113, 1100, 1581, 1582, 2090, 2616, 2620, … 5631]  │
# │ 7     ┆ [277, 278, 279, 1277, 1278, 1769, 2279, 3265, 3267, … 5778]  │
# │ 8     ┆ [40, 49, 199, 524, 697, 701, 1043, 1044, 1190, … 5816]       │
# │ 9     ┆ [178, 680, 681, 1412, 3178, 3689, 3922, 4374, 4692, … 5859]  │
# │ 10    ┆ [769, 770, 1309, 1310, 1807, 2318, 2319, 2321, 2407, … 5801] │
# └───────┴──────────────────────────────────────────────────────────────┘

# %% [markdown]
# # Step 4: Preprocess

# %% [markdown]
# ## Clear garbage charachters and digits

# %%
def clean_text(df):
    df = df.with_columns(
        pl.col("text")
        .str.replace_all(r"[.,(){}\[\]*&^%$#@!?_\-+=/\\`~'\";:]", " ") # Remove special characters
        .str.replace_all(r"\d", " ")                                   # Remove digits
        .str.replace_all(r"\s+", " ")                                  # Replace multiple whitespace with single space
        .str.strip_chars()                                             # Remove leading/trailing whitespace
    )
    return df

# %%
documents_clean = clean_text(documents)
queries_clean = clean_text(queries)

# %%
documents_clean.head(10)
# Out:
# shape: (10, 2)
# ┌───────┬─────────────────────────────────────────────────────────────────────────┐
# │ index ┆ text                                                                    │
# │ ---   ┆ ---                                                                     │
# │ i64   ┆ str                                                                     │
# ╞═══════╪═════════════════════════════════════════════════════════════════════════╡
# │ 1     ┆ THE INDIAN COUNCIL OF LIBRARY AND INFORMATION SERVICES RESEARCH AND TR… │
# │ 2     ┆ THE LINGERING FRAGRANCE PROCEEDINGS OF THE XXIV ALL INDIA LIBRARY CONF… │
# │ 3     ┆ XXV ALL INDIA LIBRARY CONFERENCE TRIVANDRUM MAY PAPERS AND PROCEEDINGS… │
# │ 4     ┆ MALAWI LIBRARY ASSOCIATION SECOND ANNUAL GENERAL MEETING CHANCELLOR CO… │
# │ 5     ┆ A PERSONAL VIEW OF THE ZAMBIA LIBRARY SERVICE PERSONAL VIEW OF THE SER… │
# │ 6     ┆ CLA TURNING ON THE POWER REPORT OF PROCEEDINGS OF THE TH ANNUAL CANADI… │
# │ 7     ┆ UNCERTAIN BEGINNINGS REPORT OF THE AMERICAN LIBRARY ASSOCIATION MIDWIN… │
# │ 8     ┆ MIDWINTER IN REAGAN S WASHINGTON AN ALA CONFERENCE REPORT REPORT OF TH… │
# │ 9     ┆ THE WHITE HOUSE CONFERENCE ON LIBRARY AND INFORMATION SERVICES SUMMARY… │
# │ 10    ┆ INFORMATION BOOKS ARE JUST THE BEGINNING THE MICHIGAN WHITE HOUSE CONF… │
# └───────┴─────────────────────────────────────────────────────────────────────────┘

# %%
queries_clean.head(10)
# Out:
# shape: (10, 2)
# ┌───────┬─────────────────────────────────────────────────────────────────────────┐
# │ index ┆ text                                                                    │
# │ ---   ┆ ---                                                                     │
# │ i64   ┆ str                                                                     │
# ╞═══════╪═════════════════════════════════════════════════════════════════════════╡
# │ 1     ┆ I AM INTERESTED IN THE IDENTIFICATION AND EVALUATION OF NOVEL COMPUTER… │
# │ 2     ┆ I WOULD BE INTERESTED TO RECEIVE INFORMATION ON NON USERS OF LIBRARIES… │
# │ 3     ┆ I AM INTERESTED IN COMPUTER DOCUMENTATION SYSTEMS FOR CHEMICAL PATENTS… │
# │ 4     ┆ I WOULD BE PLEASED TO RECEIVE ANY INFORMATION ON THE USE OF JOURNALS I… │
# │ 5     ┆ MY DISSERTATION IS AN OVERVIEW OF NEWS DATABASES LOOKING AT THE AVAILA… │
# │ 6     ┆ MY DISSERTATION IS ON LIBRARY OUTREACH FOR THE CHINESE COMMUNITY IN SH… │
# │ 7     ┆ I WOULD BE PLEASED TO RECEIVE PAPERS ON THE SECURITY OF INFORMATION IN… │
# │ 8     ┆ I AM INTERESTED IN THE PROFESSIONAL EDUCATION OF LIBRARIANS IN PARTICU… │
# │ 9     ┆ I AM INTERESTED IN THE EXTENT TO WHICH LIBRARIES ARE CHARGING FOR SERV… │
# │ 10    ┆ I AM INTERESTED IN INFORMATION ON THE PROVISION OF CURRENT AWARENESS B… │
# └───────┴─────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Lower all alphabet charachters

# %%
def lower_text(df):
    df = df.with_columns(
        pl.col("text")
        .str.to_lowercase()
    )
    return df

# %%
documents_lower = lower_text(documents_clean)
queries_lower = lower_text(queries_clean)

# %%
documents_lower.head(10)
# Out:
# shape: (10, 2)
# ┌───────┬─────────────────────────────────────────────────────────────────────────┐
# │ index ┆ text                                                                    │
# │ ---   ┆ ---                                                                     │
# │ i64   ┆ str                                                                     │
# ╞═══════╪═════════════════════════════════════════════════════════════════════════╡
# │ 1     ┆ the indian council of library and information services research and tr… │
# │ 2     ┆ the lingering fragrance proceedings of the xxiv all india library conf… │
# │ 3     ┆ xxv all india library conference trivandrum may papers and proceedings… │
# │ 4     ┆ malawi library association second annual general meeting chancellor co… │
# │ 5     ┆ a personal view of the zambia library service personal view of the ser… │
# │ 6     ┆ cla turning on the power report of proceedings of the th annual canadi… │
# │ 7     ┆ uncertain beginnings report of the american library association midwin… │
# │ 8     ┆ midwinter in reagan s washington an ala conference report report of th… │
# │ 9     ┆ the white house conference on library and information services summary… │
# │ 10    ┆ information books are just the beginning the michigan white house conf… │
# └───────┴─────────────────────────────────────────────────────────────────────────┘

# %%
queries_lower.head(10)
# Out:
# shape: (10, 2)
# ┌───────┬─────────────────────────────────────────────────────────────────────────┐
# │ index ┆ text                                                                    │
# │ ---   ┆ ---                                                                     │
# │ i64   ┆ str                                                                     │
# ╞═══════╪═════════════════════════════════════════════════════════════════════════╡
# │ 1     ┆ i am interested in the identification and evaluation of novel computer… │
# │ 2     ┆ i would be interested to receive information on non users of libraries… │
# │ 3     ┆ i am interested in computer documentation systems for chemical patents… │
# │ 4     ┆ i would be pleased to receive any information on the use of journals i… │
# │ 5     ┆ my dissertation is an overview of news databases looking at the availa… │
# │ 6     ┆ my dissertation is on library outreach for the chinese community in sh… │
# │ 7     ┆ i would be pleased to receive papers on the security of information in… │
# │ 8     ┆ i am interested in the professional education of librarians in particu… │
# │ 9     ┆ i am interested in the extent to which libraries are charging for serv… │
# │ 10    ┆ i am interested in information on the provision of current awareness b… │
# └───────┴─────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Tokenization

# %%
def tokenize_text(df, text_col="text"):
    return df.with_columns(pl.col(text_col).str.split(" ").alias("token"))

# %%
documents_tokenized = tokenize_text(documents_lower)
queries_tokenized = tokenize_text(queries_lower)

# %%
documents_tokenized.head(10)
# Out:
# shape: (10, 3)
# ┌───────┬─────────────────────────────────────────────┬────────────────────────────────────────────┐
# │ index ┆ text                                        ┆ token                                      │
# │ ---   ┆ ---                                         ┆ ---                                        │
# │ i64   ┆ str                                         ┆ list[str]                                  │
# ╞═══════╪═════════════════════════════════════════════╪════════════════════════════════════════════╡
# │ 1     ┆ the indian council of library and           ┆ ["the", "indian", "council", "of",         │
# │       ┆ information services research and tr…       ┆ "library", "and", "information", "s…       │
# │ 2     ┆ the lingering fragrance proceedings of the  ┆ ["the", "lingering", "fragrance",          │
# │       ┆ xxiv all india library conf…                ┆ "proceedings", "of", "the", "xxiv", …      │
# │ 3     ┆ xxv all india library conference trivandrum ┆ ["xxv", "all", "india", "library",         │
# │       ┆ may papers and proceedings…                 ┆ "conference", "trivandrum", "may", …       │
# │ 4     ┆ malawi library association second annual    ┆ ["malawi", "library", "association",       │
# │       ┆ general meeting chancellor co…              ┆ "second", "annual", "general", "m…         │
# │ 5     ┆ a personal view of the zambia library       ┆ ["a", "personal", "view", "of", "the",     │
# │       ┆ service personal view of the ser…           ┆ "zambia", "library", "service",…           │
# │ 6     ┆ cla turning on the power report of          ┆ ["cla", "turning", "on", "the", "power",   │
# │       ┆ proceedings of the th annual canadi…        ┆ "report", "of", "proceedings"…             │
# │ 7     ┆ uncertain beginnings report of the american ┆ ["uncertain", "beginnings", "report",      │
# │       ┆ library association midwin…                 ┆ "of", "the", "american", "librar…          │
# │ 8     ┆ midwinter in reagan s washington an ala     ┆ ["midwinter", "in", "reagan", "s",         │
# │       ┆ conference report report of th…             ┆ "washington", "an", "ala", "confere…       │
# │ 9     ┆ the white house conference on library and   ┆ ["the", "white", "house", "conference",    │
# │       ┆ information services summary…               ┆ "on", "library", "and", "infor…            │
# │ 10    ┆ information books are just the beginning    ┆ ["information", "books", "are", "just",    │
# │       ┆ the michigan white house conf…              ┆ "the", "beginning", "the", "mi…            │
# └───────┴─────────────────────────────────────────────┴────────────────────────────────────────────┘

# %%
queries_tokenized.head(10)
# Out:
# shape: (10, 3)
# ┌───────┬─────────────────────────────────────────────┬────────────────────────────────────────────┐
# │ index ┆ text                                        ┆ token                                      │
# │ ---   ┆ ---                                         ┆ ---                                        │
# │ i64   ┆ str                                         ┆ list[str]                                  │
# ╞═══════╪═════════════════════════════════════════════╪════════════════════════════════════════════╡
# │ 1     ┆ i am interested in the identification and   ┆ ["i", "am", "interested", "in", "the",     │
# │       ┆ evaluation of novel computer…               ┆ "identification", "and", "evalu…           │
# │ 2     ┆ i would be interested to receive            ┆ ["i", "would", "be", "interested", "to",   │
# │       ┆ information on non users of libraries…      ┆ "receive", "information", "on…             │
# │ 3     ┆ i am interested in computer documentation   ┆ ["i", "am", "interested", "in",            │
# │       ┆ systems for chemical patents…               ┆ "computer", "documentation", "systems"…    │
# │ 4     ┆ i would be pleased to receive any           ┆ ["i", "would", "be", "pleased", "to",      │
# │       ┆ information on the use of journals i…       ┆ "receive", "any", "information",…          │
# │ 5     ┆ my dissertation is an overview of news      ┆ ["my", "dissertation", "is", "an",         │
# │       ┆ databases looking at the availa…            ┆ "overview", "of", "news", "database…       │
# │ 6     ┆ my dissertation is on library outreach for  ┆ ["my", "dissertation", "is", "on",         │
# │       ┆ the chinese community in sh…                ┆ "library", "outreach", "for", "the"…       │
# │ 7     ┆ i would be pleased to receive papers on the ┆ ["i", "would", "be", "pleased", "to",      │
# │       ┆ security of information in…                 ┆ "receive", "papers", "on", "the"…          │
# │ 8     ┆ i am interested in the professional         ┆ ["i", "am", "interested", "in", "the",     │
# │       ┆ education of librarians in particu…         ┆ "professional", "education", "o…           │
# │ 9     ┆ i am interested in the extent to which      ┆ ["i", "am", "interested", "in", "the",     │
# │       ┆ libraries are charging for serv…            ┆ "extent", "to", "which", "libra…           │
# │ 10    ┆ i am interested in information on the       ┆ ["i", "am", "interested", "in",            │
# │       ┆ provision of current awareness b…           ┆ "information", "on", "the", "provision…    │
# └───────┴─────────────────────────────────────────────┴────────────────────────────────────────────┘

# %% [markdown]
# ## Word Counting

# %%
def count_words(df, token_col="token"):
    all_tokens = [word for tokens in df[token_col].to_list() for word in tokens if word != ""]
    word_counts = Counter(all_tokens)
    unique_words = set(word_counts.keys())
    return pl.DataFrame({"word": list(word_counts.keys()), "count": list(word_counts.values())}).sort("count", descending=True), len(unique_words)

# %%
documents_counted, documents_uniqe = count_words(documents_tokenized)
queries_counted, queries_uniqe = count_words(queries_tokenized)

# %%
documents_uniqe
# Out:
# 17654

# %%
queries_uniqe
# Out:
# 585

# %%
documents_counted.head(10)
# Out:
# shape: (10, 2)
# ┌─────────────┬───────┐
# │ word        ┆ count │
# │ ---         ┆ ---   │
# │ str         ┆ i64   │
# ╞═════════════╪═══════╡
# │ the         ┆ 41413 │
# │ of          ┆ 30371 │
# │ and         ┆ 24998 │
# │ in          ┆ 15028 │
# │ to          ┆ 12146 │
# │ a           ┆ 11591 │
# │ library     ┆ 8693  │
# │ for         ┆ 7981  │
# │ information ┆ 5670  │
# │ on          ┆ 5386  │
# └─────────────┴───────┘

# %%
queries_counted.head(10)
# Out:
# shape: (10, 2)
# ┌─────────────┬───────┐
# │ word        ┆ count │
# │ ---         ┆ ---   │
# │ str         ┆ i64   │
# ╞═════════════╪═══════╡
# │ in          ┆ 78    │
# │ of          ┆ 78    │
# │ the         ┆ 72    │
# │ and         ┆ 62    │
# │ i           ┆ 55    │
# │ information ┆ 53    │
# │ am          ┆ 31    │
# │ interested  ┆ 31    │
# │ on          ┆ 30    │
# │ to          ┆ 29    │
# └─────────────┴───────┘

# %% [markdown]
# ## Show Zipf Law

# %%
def plot_zipf_distribution(word_freq_df):
    ranks = np.arange(1, len(word_freq_df) + 1)
    frequencies = word_freq_df["count"].to_numpy()

    plt.figure(figsize=(6, 3))
    plt.loglog(ranks, frequencies, marker="o", linestyle="none", label="Observed Data")
    plt.xlabel("Rank (log)")
    plt.ylabel("Frequency (log)")
    plt.title("Zipf's Law Distribution of Word Frequencies")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_zipf_distribution(documents_counted)

# %%
plot_zipf_distribution(queries_counted)

# %% [markdown]
# ## Calculate stop and steⅿⅿing words

# %%
def filter_words_by_frequency(word_freq_df, min_count=25, max_count_ratio=0.005):
    total_words = word_freq_df["count"].sum()
    max_count = total_words * max_count_ratio

    filtered_df = word_freq_df.filter(
        (pl.col("count") >= min_count) &
        (pl.col("count") <= max_count)
    )

    removed_words = set(word_freq_df["word"].to_list()) - set(filtered_df["word"].to_list())
    removed_words.add("")
    return filtered_df, removed_words

# %%
_, removal_words = filter_words_by_frequency(documents_counted)

documents_removed = documents_counted.filter(
    ~pl.col("word").is_in(list(removal_words))
)

queries_removed = queries_counted.filter(
    ~pl.col("word").is_in(list(removal_words))
)

# %%
documents_removed.head(10)
# Out:
# shape: (10, 2)
# ┌──────────┬───────┐
# │ word     ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ i64   │
# ╞══════════╪═══════╡
# │ an       ┆ 2633  │
# │ be       ┆ 2620  │
# │ that     ┆ 2341  │
# │ at       ┆ 2334  │
# │ from     ┆ 2271  │
# │ which    ┆ 2216  │
# │ services ┆ 2104  │
# │ public   ┆ 2074  │
# │ system   ┆ 2044  │
# │ data     ┆ 2005  │
# └──────────┴───────┘

# %%
queries_removed.head(10)
# Out:
# shape: (10, 2)
# ┌────────────┬───────┐
# │ word       ┆ count │
# │ ---        ┆ ---   │
# │ str        ┆ i64   │
# ╞════════════╪═══════╡
# │ i          ┆ 55    │
# │ interested ┆ 31    │
# │ be         ┆ 25    │
# │ would      ┆ 21    │
# │ systems    ┆ 21    │
# │ or         ┆ 18    │
# │ any        ┆ 18    │
# │ education  ┆ 14    │
# │ retrieval  ┆ 14    │
# │ use        ┆ 12    │
# └────────────┴───────┘

# %%
removal_words
# Out:
# {'',
#  'vigorously',
#  'philanthropic',
#  'dual',
#  'mo',
#  'lexicography',
#  'switchboards',
#  'remained',
#  'purchased',
#  'relieved',
#  'finalised',
#  'evolving',
#  'internships',
#  'vertex',
#  'captioned',
#  'documate',
#  'adaptive',
#  'inaccuracies',
#  'interrogated',
#  'ruled',
#  'bakewell',
#  'restrained',
#  'clann',
#  'convert',
#  'sterilisation',
#  'opens',
#  'easing',
#  'coordinates',
#  'jahoda',
#  'surgeon',
#  'attract',
#  'booktalk',
#  'belles',
#  'nursery',
#  'capitalisation',
#  'termites',
#  'picon',
#  'leasing',
#  'wyoming',
#  'parochial',
#  'explain',
#  'telesystemes',
#  'punishable',
#  'purposely',
#  'butron',
#  'repor',
#  'route',
#  'demographics',
#  'inion',
#  'jawaharlal',
#  'thematically',
#  'grimsby',
#  'repercussions',
#  'momentum',
#  'lebesgue',
#  'fics',
#  'properly',
#  'oss',
#  'crafting',
#  'restructured',
#  'omputers',
#  'griffith',
#  'seem',
#  'acknowledged',
#  'break',
#  'individualized',
#  'bottle',
#  'deficiencies',
#  'cells',
#  'politicisation',
#  'drols',
#  'crime',
#  'mismanagement',
#  'channelled',
#  'mct',
#  'similarly',
#  'hermetically',
#  'grounds',
#  'ctenar',
#  'subgraph',
#  'tutor',
#  'durability',
#  'saturdays',
#  'slides',
#  'maintains',
#  'squarely',
#  'monetary',
#  'juxtaposition',
#  'envisaged',
#  'breakthroughs',
#  'behalf',
#  'holmes',
#  'jennings',
#  'russia',
#  'arketed',
#  'evidenced',
#  'studi',
#  'shift',
#  'gmds',
#  'generalist',
#  'yellow',
#  'heard',
#  'duplicators',
#  'victory',
#  'exploring',
#  'respite',
#  'montserrat',
#  'unhelpful',
#  'assessments',
#  'polyester',
#  'overlay',
#  'purport',
#  'corroborating',
#  'emi',
#  'fieldworkers',
#  'summarise',
#  'scans',
#  'haya',
#  'threshold',
#  'ortega',
#  'elaborate',
#  'freie',
#  'preprofessional',
#  'assimilated',
#  'antagonism',
#  'slavonic',
#  'waldo',
#  'outstanding',
#  'gulf',
#  'wealth',
#  'situated',
#  'nhs',
#  'resorts',
#  'vastly',
#  'condoning',
#  'archetype',
#  'strengthen',
#  'comla',
#  'wh',
#  'asises',
#  'cries',
#  'nottingham',
#  'tidende',
#  'rarities',
#  'szombathely',
#  'technicke',
#  'favourites',
#  'speculative',
#  'diagnosis',
#  'induced',
#  'accesses',
#  'donate',
#  'uprising',
#  'hertofore',
#  'al',
#  'presenter',
#  'nickety',
#  'incompatability',
#  'pseudonym',
#  'rational',
#  'festschriften',
#  'wants',
#  'operationally',
#  'tatti',
#  'characterizing',
#  'appetite',
#  'kharkov',
#  'pirates',
#  'munchen',
#  'jonstrup',
#  'fire',
#  'pollution',
#  'sacrifices',
#  'narrow',
#  'kacs',
#  'tensions',
#  'senate',
#  'pose',
#  'vms',
#  'dialectics',
#  'twin',
#  'substituents',
#  'monuments',
#  'paul',
#  'aerial',
#  'derivation',
#  'libtrad',
#  'longitudinal',
#  'diversity',
#  'arrears',
#  'emery',
#  'ruhr',
#  'boyle',
#  'oversewn',
#  'briefer',
#  'wedgeworth',
#  'acquiring',
#  'wednesdays',
#  'burton',
#  'enrol',
#  'documentalists',
#  'dearden',
#  'integrating',
#  'ryhma',
#  'reorganising',
#  'massachusetts',
#  'justifiably',
#  'electrographic',
#  'liverpool',
#  'gymnasium',
#  'ultimate',
#  'edgar',
#  'segregating',
#  'von',
#  'flats',
#  'analytics',
#  'inka',
#  'opava',
#  'bohus',
#  'rotnac',
#  'fi',
#  'thrust',
#  'unsparingly',
#  'fruits',
#  'immense',
#  'norton',
#  'prevision',
#  'telecopier',
#  'externally',
#  'winter',
#  'koordinatsionnyi',
#  'fachschulwesen',
#  'wishing',
#  'negligible',
#  'impossibility',
#  'uded',
#  'persuasive',
#  'temperature',
#  'extends',
#  'tabled',
#  'dame',
#  'res',
#  'indias',
#  'ws',
#  'bernard',
#  'kernel',
#  'grantsmanship',
#  'tempted',
#  'ipcs',
#  'presently',
#  'wuch',
#  'borrower',
#  'hempstead',
#  'islev',
#  'dyes',
#  'premier',
#  'nevertheless',
#  'weed',
#  'noncompatibility',
#  'filtering',
#  'modeling',
#  'metafile',
#  'tcom',
#  'kanuzu',
#  'monasteries',
#  'indications',
#  'utilities',
#  'anneliese',
#  'stranmillis',
#  'generates',
#  'timeliness',
#  'possessed',
#  'critiques',
#  'preceding',
#  'simplifying',
#  'herbaria',
#  'pors',
#  'radcliffe',
#  'chinoin',
#  'ivan',
#  'danmedia',
#  'biographies',
#  'bahamas',
#  'pushkin',
#  'omission',
#  'demonstration',
#  'analytic',
#  'curatorship',
#  'botevgrad',
#  'recalling',
#  'legis',
#  'explanatory',
#  'catastrophe',
#  'separating',
#  'schlesinger',
#  'lyceum',
#  'negotiation',
#  'acquainting',
#  'algebra',
#  'reproduces',
#  'emmission',
#  'underrated',
#  'transparent',
#  'caught',
#  'singleton',
#  'eurodata',
#  'horrocks',
#  'isomorphism',
#  'saskatchewan',
#  'bookfund',
#  'kil',
#  'impacting',
#  'satirical',
#  'expurgate',
#  'complexities',
#  'carpets',
#  'mystiques',
#  'displayer',
#  'rebuts',
#  'dose',
#  'accustom',
#  'proof',
#  'migrants',
#  'salmonsen',
#  'electricity',
#  'creators',
#  'repairing',
#  'minimise',
#  'lapps',
#  'juel',
#  'cocitation',
#  'ynopses',
#  'quantities',
#  'mosque',
#  'taxes',
#  'enjoyable',
#  'newsreel',
#  'stipulating',
#  'fragments',
#  'gifts',
#  'vidmo',
#  'exposes',
#  'blindness',
#  'misapplication',
#  'couple',
#  'congresswoman',
#  'reunion',
#  'musik',
#  'gombocz',
#  'ecssid',
#  'idrc',
#  'peter',
#  'encounters',
#  'don',
#  'konrad',
#  'strains',
#  'truthfully',
#  'unselected',
#  'xi',
#  'ulscs',
#  'ireland',
#  'gmbh',
#  'lopez',
#  'creditable',
#  'validation',
#  'casc',
#  'opera',
#  'strengthened',
#  'omics',
#  'screen',
#  'secrets',
#  'stephenson',
#  'patentability',
#  'innovators',
#  'atari',
#  'inteligent',
#  'lying',
#  'reserves',
#  'marjorie',
#  'malmo',
#  'brith',
#  'entitled',
#  'firs',
#  'amendments',
#  'ratios',
#  'turku',
#  'andre',
#  'librari',
#  'manufacture',
#  'extranea',
#  'reworking',
#  'witnessed',
#  'dialectical',
#  'ns',
#  'balance',
#  'caracas',
#  'avenue',
#  'startup',
#  'dalhousie',
#  'useless',
#  'operators',
#  'concentrated',
#  'infrequently',
#  'inspirations',
#  'msc',
#  'mature',
#  'gosudarstvennyi',
#  'educationists',
#  'tis',
#  'olds',
#  'victors',
#  'novice',
#  'faye',
#  'expands',
#  'trace',
#  'interprocess',
#  'harmonise',
#  'ascribed',
#  'parapsychology',
#  'alike',
#  'vermont',
#  'elevators',
#  'microcatalogue',
#  'weekdays',
#  'manitoba',
#  'packets',
#  'programing',
#  'translating',
#  'scattering',
#  'marchetti',
#  'prepaid',
#  'indoor',
#  'diocese',
#  'isbn',
#  'brandis',
#  'experiential',
#  'justifying',
#  'iall',
#  'grips',
#  'latino',
#  'neurotically',
#  'systemwide',
#  'swansea',
#  'stores',
#  'logistics',
#  'promise',
#  'aimak',
#  'interim',
#  'typographical',
#  'proving',
#  'asean',
#  'nakskov',
#  'keen',
#  'dunn',
#  'differentiate',
#  'cranfield',
#  'attibutes',
#  'qcldb',
#  'fisheries',
#  'plmru',
#  'welding',
#  'providence',
#  'inmate',
#  'atlantic',
#  'approximate',
#  'coastal',
#  'sargeant',
#  'kuhl',
#  'winner',
#  'int',
#  'bcr',
#  'stanford',
#  'habermann',
#  'unionisation',
#  'supplemental',
#  'fatigue',
#  'dwells',
#  'algorithms',
#  'sing',
#  'pisa',
#  'necessitated',
#  'ergonomic',
#  'frewen',
#  'info',
#  'gpo',
#  'moie',
#  'burn',
#  'amounting',
#  'mouse',
#  'cole',
#  'incentives',
#  'entropy',
#  'friendship',
#  'grigore',
#  'minefield',
#  'bramley',
#  'multitype',
#  'broadest',
#  'kayser',
#  'und',
#  'announced',
#  'arie',
#  'phenomenon',
#  'rudolph',
#  'nonsilver',
#  'clara',
#  'cinematographers',
#  'cronos',
#  'constraint',
#  'firstly',
#  'vulnerable',
#  'peoples',
#  'engine',
#  'tremendously',
#  'insofar',
#  'nitrate',
#  'decreased',
#  'vocal',
#  'putting',
#  'departure',
#  'datalogical',
#  'prefers',
#  'economists',
#  'kartashov',
#  'challenged',
#  'grou',
#  'ken',
#  'countered',
#  'eager',
#  'interpenetration',
#  'telling',
#  'touches',
#  'maslow',
#  'seepage',
#  'sharp',
#  'cartographie',
#  'arthur',
#  'mechanisms',
#  'recompensed',
#  'sutz',
#  'ais',
#  'atheism',
#  'aachen',
#  'intrinsic',
#  'microsize',
#  'octopus',
#  'prints',
#  'centrales',
#  'bignon',
#  'wilhelm',
#  'absolutely',
#  'carelessness',
#  'nfais',
#  'toys',
#  'wolf',
#  'ing',
#  'assertations',
#  'ncui',
#  'cane',
#  'zeitungsbestande',
#  'wee',
#  'convergence',
#  'randomly',
#  'rasd',
#  'screened',
#  'medicus',
#  'elt',
#  'impacts',
#  'successor',
#  'nci',
#  'ensuring',
#  'traffic',
#  'completeness',
#  'arbitrary',
#  'markings',
#  'preliterate',
#  'centredoc',
#  'literatuuronderzoekers',
#  'designs',
#  'ancestry',
#  'proportional',
#  'barry',
#  'impudent',
#  'wln',
#  'workplaces',
#  'princeton',
#  'resew',
#  'merchants',
#  'treaties',
#  'constituents',
#  'differ',
#  'presidency',
#  'lication',
#  'destination',
#  'ic',
#  'topping',
#  'domain',
#  'optimisation',
#  'flair',
#  'reporter',
#  'damp',
#  'festivals',
#  'heishman',
#  'hunnold',
#  'confusing',
#  'broome',
#  'reluctant',
#  'cim',
#  'barwick',
#  'eileen',
#  'subscribed',
#  'decries',
#  'provins',
#  'sort',
#  'westphalia',
#  'lag',
#  'suggesting',
#  'springs',
#  'lappish',
#  'introductions',
#  'fier',
#  'sharers',
#  'dwellers',
#  'antonio',
#  'explicating',
#  'coexisting',
#  'indispensible',
#  'lump',
#  'stockholm',
#  'permissive',
#  'investment',
#  'teleprinters',
#  'with',
#  'seems',
#  'fm',
#  'defaulted',
#  'timely',
#  'wasted',
#  'adp',
#  'dispensed',
#  'ruined',
#  'disaster',
#  'cip',
#  'bookrack',
#  'apprehension',
#  'medians',
#  'continental',
#  'overviewed',
#  'distinguished',
#  'mineral',
#  'psi',
#  'hbo',
#  'ct',
#  'rostock',
#  'interlocking',
#  'dienste',
#  'eales',
#  'transfers',
#  'discovering',
#  'carnegies',
#  'agro',
#  'perish',
#  'heiress',
#  'reservations',
#  'nnual',
#  'anticipated',
#  'smoke',
#  'persistence',
#  'precedents',
#  'clothing',
#  'enormous',
#  'sff',
#  'secretarial',
#  'injuries',
#  'kylberg',
#  'bokfortegnelse',
#  'confined',
#  'constituting',
#  'implicitly',
#  'grades',
#  'insurers',
#  'requesting',
#  'strained',
#  'benefited',
#  'bibliografia',
#  'binds',
#  'sensitivity',
#  'saloon',
#  'reagan',
#  'metainformation',
#  'paperback',
#  'speculate',
#  'advisability',
#  'imbued',
#  'electrons',
#  'mommsen',
#  'hansjorg',
#  'concerted',
#  'positions',
#  'myer',
#  'barr',
#  'silly',
#  'downhill',
#  'substructure',
#  'eschews',
#  'circuit',
#  'beneficial',
#  'epc',
#  'normalisation',
#  'swedify',
#  'native',
#  'inferior',
#  'angermann',
#  'convening',
#  'pendix',
#  'unhurriedly',
#  'arabization',
#  'evident',
#  'outhouse',
#  'informing',
#  'complaints',
#  'eruption',
#  'guerilla',
#  'childers',
#  'assimilate',
#  'prognoses',
#  'attractions',
#  'customs',
#  'remit',
#  'scintillation',
#  'abysmally',
#  'redundancies',
#  'rehoused',
#  'ortf',
#  'cakes',
#  'jurisdiction',
#  'deviant',
#  'fiji',
#  'lewis',
#  'originated',
#  'unprocessed',
#  'subsidiaries',
#  'linc',
#  'nauchnotekhnicheskoi',
#  'latecomers',
#  'spoor',
#  'convenient',
#  'bibliothekswesen',
#  'honour',
#  'paralleled',
#  'secondly',
#  'desires',
#  'adjacent',
#  'samarc',
#  'baden',
#  'witness',
#  'desire',
#  'relatives',
#  'playing',
#  'pronunciation',
#  'ready',
#  'influencing',
#  'volatile',
#  'primer',
#  'uvli',
#  'overcrowding',
#  'friends',
#  'brigham',
#  'polygraphy',
#  'policymakers',
#  'thematical',
#  'biologically',
#  'observer',
#  'solely',
#  'contemplation',
#  'associates',
#  'amerbach',
#  'deis',
#  'richardson',
#  'diagrammatically',
#  'camden',
#  'agdoc',
#  'ees',
#  'oblastnaya',
#  'laach',
#  'pipe',
#  'mantua',
#  'depending',
#  'kiril',
#  'asfis',
#  'turnovo',
#  'nottinghamshire',
#  'mutagenicity',
#  'academics',
#  'familiarisation',
#  'disruption',
#  'surface',
#  'hochschule',
#  'comecon',
#  'primitives',
#  'disguised',
#  'sma',
#  'typesets',
#  'gas',
#  'arl',
#  'arithmetic',
#  'orthography',
#  'rovides',
#  'cancer',
#  'striving',
#  'heterogeneity',
#  'moskovskii',
#  'concert',
#  'and',
#  'toxicological',
#  'perturbing',
#  'gdr',
#  'laboring',
#  'nassau',
#  'thermal',
#  'superseding',
#  'blackwell',
#  'understandable',
#  'penalties',
#  'compartments',
#  'default',
#  'griebl',
#  'triplicate',
#  'embodies',
#  'forcing',
#  'bookseller',
#  'blld',
#  'syntactic',
#  'eads',
#  'curley',
#  'modification',
#  'nornal',
#  'piece',
#  'circe',
#  'sequence',
#  'aggregated',
#  'cartographic',
#  'regulate',
#  'incorporating',
#  'adlib',
#  'graphite',
#  'span',
#  'uncommon',
#  'uncharted',
#  'invented',
#  'bildschirmtext',
#  'troubles',
#  'visually',
#  'elusive',
#  'indianapolis',
#  'none',
#  'heuristics',
#  'cortland',
#  'mobilise',
#  'imply',
#  'partitioning',
#  'leavers',
#  'instigators',
#  'wade',
#  'practicability',
#  'slope',
#  'oblivion',
#  'enquirers',
#  'rml',
#  'sketches',
#  'disappointments',
#  'napis',
#  'napa',
#  'bauds',
#  'inherent',
#  'clackamas',
#  'participatory',
#  'perplexing',
#  'burchell',
#  'bounds',
#  'louisville',
#  'postharvest',
#  'cairo',
#  'mastered',
#  'incurred',
#  'reska',
#  'knox',
#  'proficient',
#  'pirkko',
#  'toomly',
#  'regeln',
#  'sports',
#  'tion',
#  'eva',
#  'disconnection',
#  'boys',
#  'summing',
#  'agricola',
#  'hearts',
#  'toilets',
#  'harjedalen',
#  'committed',
#  'instant',
#  'sponsorship',
#  'discontinue',
#  'tammisaari',
#  'romanized',
#  'postage',
#  'inservice',
#  'locke',
#  'credibility',
#  'noun',
#  'teleordering',
#  'renounced',
#  'reevaluating',
#  'origination',
#  'cooper',
#  'tax',
#  'li',
#  'journalists',
#  'gauze',
#  'gaining',
#  'prize',
#  'candy',
#  'abuses',
#  'choir',
#  'questioning',
#  'chains',
#  'opposing',
#  'remedied',
#  'shipping',
#  'normalised',
#  'blend',
#  'ieee',
#  'constituent',
#  'cons',
#  'folded',
#  'demography',
#  'versatile',
#  'unification',
#  'castle',
#  'cifc',
#  'star',
#  'disorders',
#  'provider',
#  'anonymity',
#  'cia',
#  'suspension',
#  'sensible',
#  'imperialist',
#  'digitised',
#  'tank',
#  'formatted',
#  'vols',
#  'calendars',
#  'wittgenstein',
#  'diminished',
#  'gratefully',
#  'menuryang',
#  'preconferences',
#  'rateable',
#  'enhanced',
#  'achievement',
#  'consistencies',
#  'verified',
#  'wetenschappen',
#  'od',
#  'doctor',
#  'ferris',
#  'herself',
#  'keeper',
#  'infrared',
#  'cowpeas',
#  'photocopier',
#  'videotext',
#  'dissenting',
#  'fwa',
#  'underflow',
#  'cm',
#  'misspelling',
#  'faith',
#  'ama',
#  'deduces',
#  'catvlib',
#  'artists',
#  'parvo',
#  'psychologie',
#  'refusal',
#  'precautions',
#  'mimeographed',
#  'recounts',
#  'gay',
#  'ut',
#  'codification',
#  'focke',
#  'odin',
#  'mammoth',
#  'kirtipur',
#  'afterword',
#  'coffee',
#  ...}

# %% [markdown]
# ## Remove stop and steⅿⅿing words

# %%
def remove_abandon_words(df, remove_word_list, token_col="token"):
    return df.with_columns(
        pl.col(token_col).list.eval(
            pl.element().filter(pl.element().is_in(remove_word_list).not_())
        ).alias(token_col)
    )

# %%
documents_refined = remove_abandon_words(documents_tokenized, removal_words)
queries_refined = remove_abandon_words(queries_tokenized, removal_words)

# %%
documents_refined.head(10)
# Out:
# shape: (10, 3)
# ┌───────┬─────────────────────────────────────────────┬────────────────────────────────────────────┐
# │ index ┆ text                                        ┆ token                                      │
# │ ---   ┆ ---                                         ┆ ---                                        │
# │ i64   ┆ str                                         ┆ list[str]                                  │
# ╞═══════╪═════════════════════════════════════════════╪════════════════════════════════════════════╡
# │ 1     ┆ the indian council of library and           ┆ ["indian", "council", "services",          │
# │       ┆ information services research and tr…       ┆ "research", "training", "proposal", …      │
# │ 2     ┆ the lingering fragrance proceedings of the  ┆ ["proceedings", "all", "india",            │
# │       ┆ xxiv all india library conf…                ┆ "conference", "papers", "proceedings",…    │
# │ 3     ┆ xxv all india library conference trivandrum ┆ ["all", "india", "conference", "may",      │
# │       ┆ may papers and proceedings…                 ┆ "papers", "proceedings", "confer…          │
# │ 4     ┆ malawi library association second annual    ┆ ["association", "annual", "general",       │
# │       ┆ general meeting chancellor co…              ┆ "meeting", "college", "summary", …         │
# │ 5     ┆ a personal view of the zambia library       ┆ ["personal", "view", "service",            │
# │       ┆ service personal view of the ser…           ┆ "personal", "view", "service", "based"…    │
# │ 6     ┆ cla turning on the power report of          ┆ ["power", "report", "proceedings", "th",   │
# │       ┆ proceedings of the th annual canadi…        ┆ "annual", "canadian", "associ…             │
# │ 7     ┆ uncertain beginnings report of the american ┆ ["report", "american", "association",      │
# │       ┆ library association midwin…                 ┆ "meeting", "washington", "jan", …          │
# │ 8     ┆ midwinter in reagan s washington an ala     ┆ ["washington", "an", "ala", "conference",  │
# │       ┆ conference report report of th…             ┆ "report", "report", "america…              │
# │ 9     ┆ the white house conference on library and   ┆ ["white", "house", "conference",           │
# │       ┆ information services summary…               ┆ "services", "summary", "an", "abstrac…     │
# │ 10    ┆ information books are just the beginning    ┆ ["books", "just", "beginning", "white",    │
# │       ┆ the michigan white house conf…              ┆ "house", "conference", "servic…            │
# └───────┴─────────────────────────────────────────────┴────────────────────────────────────────────┘

# %%
queries_refined.head(10)
# Out:
# shape: (10, 3)
# ┌───────┬─────────────────────────────────────────────┬────────────────────────────────────────────┐
# │ index ┆ text                                        ┆ token                                      │
# │ ---   ┆ ---                                         ┆ ---                                        │
# │ i64   ┆ str                                         ┆ list[str]                                  │
# ╞═══════╪═════════════════════════════════════════════╪════════════════════════════════════════════╡
# │ 1     ┆ i am interested in the identification and   ┆ ["i", "interested", "identification",      │
# │       ┆ evaluation of novel computer…               ┆ "evaluation", "computer", "incre…          │
# │ 2     ┆ i would be interested to receive            ┆ ["i", "would", "be", "interested",         │
# │       ┆ information on non users of libraries…      ┆ "receive", "non", "users", "includi…       │
# │ 3     ┆ i am interested in computer documentation   ┆ ["i", "interested", "computer",            │
# │       ┆ systems for chemical patents…               ┆ "documentation", "systems", "chemical"…    │
# │ 4     ┆ i would be pleased to receive any           ┆ ["i", "would", "be", "receive", "any",     │
# │       ┆ information on the use of journals i…       ┆ "use", "journals", "any", "type…           │
# │ 5     ┆ my dissertation is an overview of news      ┆ ["dissertation", "an", "overview", "news", │
# │       ┆ databases looking at the availa…            ┆ "at", "availability", "cont…               │
# │ 6     ┆ my dissertation is on library outreach for  ┆ ["dissertation", "chinese", "community",   │
# │       ┆ the chinese community in sh…                ┆ "but", "i", "would", "be", "i…             │
# │ 7     ┆ i would be pleased to receive papers on the ┆ ["i", "would", "be", "receive", "papers",  │
# │       ┆ security of information in…                 ┆ "security", "databanks", "or…              │
# │ 8     ┆ i am interested in the professional         ┆ ["i", "interested", "professional",        │
# │       ┆ education of librarians in particu…         ┆ "education", "librarians", "partic…        │
# │ 9     ┆ i am interested in the extent to which      ┆ ["i", "interested", "extent", "which",     │
# │       ┆ libraries are charging for serv…            ┆ "services", "this", "public", "…           │
# │ 10    ┆ i am interested in information on the       ┆ ["i", "interested", "provision",           │
# │       ┆ provision of current awareness b…           ┆ "current", "awareness", "especially",…     │
# └───────┴─────────────────────────────────────────────┴────────────────────────────────────────────┘

# %% [markdown]
# # Step 5: Calculate the Skip-Gram Model

# %%
sentences = documents_refined["token"].to_list()

# %%
skip_gram_model = Word2Vec(sentences=sentences, vector_size=100, window=5, min_count=1, workers=4, sg=1)

# sentences: your tokenized text data (list of list of words)
# vector_size: size of the embedding vector (e.g. 100)
# window: context window size (e.g. 5)
# min_count: ignore words with total frequency lower than this
# workers: number of threads
# sg=1: use skip-gram (set sg=0 to use CBOW instead)

# %% [markdown]
# # Step 6: Calculate Average Word Vectors

# %%
def average_vector(tokens, model):
    vectors = []
    for word in tokens:
        if word in model.wv:
            vectors.append(model.wv[word])

    if len(vectors) == 0:
        return np.zeros(model.vector_size)

    sum_vector = np.zeros(model.vector_size)
    for vec in vectors:
        sum_vector += vec
    avg_vector = sum_vector / len(vectors)

    return avg_vector

# %%
def add_average_vector_column(df: pl.DataFrame, model) -> pl.DataFrame:
    tokens_list = df["token"].to_list()

    avg_vectors = []
    for tokens in tokens_list:
        vectors = []
        for word in tokens:
            if word in model.wv:
                vectors.append(model.wv[word])

        if len(vectors) == 0:
            avg = np.zeros(model.vector_size)
        else:
            sum_vector = np.zeros(model.vector_size)
            for vec in vectors:
                sum_vector += vec
            avg = sum_vector / len(vectors)

        avg_vectors.append(avg)

    df = df.with_columns([
        pl.Series("avg_vector", avg_vectors)
    ])

    return df

# %%
documents = add_average_vector_column(documents_refined, skip_gram_model)
queries = add_average_vector_column(queries_refined, skip_gram_model)

# %%
documents.head(10)
# Out:
# shape: (10, 4)
# ┌───────┬──────────────────────────────┬─────────────────────────────┬─────────────────────────────┐
# │ index ┆ text                         ┆ token                       ┆ avg_vector                  │
# │ ---   ┆ ---                          ┆ ---                         ┆ ---                         │
# │ i64   ┆ str                          ┆ list[str]                   ┆ array[f64, 100]             │
# ╞═══════╪══════════════════════════════╪═════════════════════════════╪═════════════════════════════╡
# │ 1     ┆ the indian council of        ┆ ["indian", "council",       ┆ [-0.049454, 0.117085,       │
# │       ┆ library and information      ┆ "services", "research",     ┆ -0.033157, 0.004082,        │
# │       ┆ services research and tr…    ┆ "training", "proposal", …   ┆ 0.005111, -0.210757,        │
# │       ┆                              ┆                             ┆ 0.0850…                     │
# │ 2     ┆ the lingering fragrance      ┆ ["proceedings", "all",      ┆ [-0.044638, 0.231398,       │
# │       ┆ proceedings of the xxiv all  ┆ "india", "conference",      ┆ -0.210557, -0.005695,       │
# │       ┆ india library conf…          ┆ "papers", "proceedings",…   ┆ -0.116361, -0.101918, 0.22… │
# │ 3     ┆ xxv all india library        ┆ ["all", "india",            ┆ [0.054224, 0.073524,        │
# │       ┆ conference trivandrum may    ┆ "conference", "may",        ┆ -0.148463, -0.080995,       │
# │       ┆ papers and proceedings…      ┆ "papers", "proceedings",    ┆ -0.155908, -0.149399,       │
# │       ┆                              ┆ "confer…                    ┆ 0.203…                      │
# │ 4     ┆ malawi library association   ┆ ["association", "annual",   ┆ [-0.013024, 0.130635,       │
# │       ┆ second annual general        ┆ "general", "meeting",       ┆ -0.144958, -0.071856,       │
# │       ┆ meeting chancellor co…       ┆ "college", "summary", …     ┆ -0.093662, -0.17239, 0.116… │
# │ 5     ┆ a personal view of the       ┆ ["personal", "view",        ┆ [-0.062471, 0.088358,       │
# │       ┆ zambia library service       ┆ "service", "personal",      ┆ 0.0293, -0.015205,          │
# │       ┆ personal view of the ser…    ┆ "view", "service", "based"… ┆ 0.018374, -0.221316,        │
# │       ┆                              ┆                             ┆ 0.090376…                   │
# │ 6     ┆ cla turning on the power     ┆ ["power", "report",         ┆ [-0.013719, 0.121887,       │
# │       ┆ report of proceedings of the ┆ "proceedings", "th",        ┆ -0.137465, -0.089107,       │
# │       ┆ th annual canadi…            ┆ "annual", "canadian",       ┆ -0.117776, -0.090444, 0.14… │
# │       ┆                              ┆ "associ…                    ┆                             │
# │ 7     ┆ uncertain beginnings report  ┆ ["report", "american",      ┆ [-0.093186, 0.228075,       │
# │       ┆ of the american library      ┆ "association", "meeting",   ┆ -0.078092, 0.002329,        │
# │       ┆ association midwin…          ┆ "washington", "jan", …      ┆ -0.149291, -0.14732,        │
# │       ┆                              ┆                             ┆ 0.1602…                     │
# │ 8     ┆ midwinter in reagan s        ┆ ["washington", "an", "ala", ┆ [-0.0283, 0.335289,         │
# │       ┆ washington an ala conference ┆ "conference", "report",     ┆ -0.16296, -0.028053,        │
# │       ┆ report report of th…         ┆ "report", "america…         ┆ -0.162692, -0.160405,       │
# │       ┆                              ┆                             ┆ 0.16601…                    │
# │ 9     ┆ the white house conference   ┆ ["white", "house",          ┆ [-0.070691, 0.345716,       │
# │       ┆ on library and information   ┆ "conference", "services",   ┆ -0.150816, 0.090985,        │
# │       ┆ services summary…            ┆ "summary", "an", "abstrac…  ┆ -0.03951, 0.026758,         │
# │       ┆                              ┆                             ┆ 0.29259…                    │
# │ 10    ┆ information books are just   ┆ ["books", "just",           ┆ [-0.060696, 0.203081,       │
# │       ┆ the beginning the michigan   ┆ "beginning", "white",       ┆ -0.119938, -0.037227,       │
# │       ┆ white house conf…            ┆ "house", "conference",      ┆ -0.064296, -0.11287, 0.173… │
# │       ┆                              ┆ "servic…                    ┆                             │
# └───────┴──────────────────────────────┴─────────────────────────────┴─────────────────────────────┘

# %%
queries.head(10)
# Out:
# shape: (10, 4)
# ┌───────┬──────────────────────────────┬─────────────────────────────┬─────────────────────────────┐
# │ index ┆ text                         ┆ token                       ┆ avg_vector                  │
# │ ---   ┆ ---                          ┆ ---                         ┆ ---                         │
# │ i64   ┆ str                          ┆ list[str]                   ┆ array[f64, 100]             │
# ╞═══════╪══════════════════════════════╪═════════════════════════════╪═════════════════════════════╡
# │ 1     ┆ i am interested in the       ┆ ["i", "interested",         ┆ [-0.13894, 0.142247,        │
# │       ┆ identification and           ┆ "identification",           ┆ 0.002149, 0.013505,         │
# │       ┆ evaluation of novel          ┆ "evaluation", "computer",   ┆ -0.008679, -0.223034,       │
# │       ┆ computer…                    ┆ "incre…                     ┆ 0.14553…                    │
# │ 2     ┆ i would be interested to     ┆ ["i", "would", "be",        ┆ [-0.091804, 0.054919,       │
# │       ┆ receive information on non   ┆ "interested", "receive",    ┆ -0.000247, 0.028991,        │
# │       ┆ users of libraries…          ┆ "non", "users", "includi…   ┆ 0.021356, -0.176705,        │
# │       ┆                              ┆                             ┆ 0.1188…                     │
# │ 3     ┆ i am interested in computer  ┆ ["i", "interested",         ┆ [-0.173938, 0.281058,       │
# │       ┆ documentation systems for    ┆ "computer",                 ┆ 0.001497, 0.079008,         │
# │       ┆ chemical patents…            ┆ "documentation", "systems", ┆ 0.000976, -0.16276,         │
# │       ┆                              ┆ "chemical"…                 ┆ 0.159992…                   │
# │ 4     ┆ i would be pleased to        ┆ ["i", "would", "be",        ┆ [-0.045151, 0.034076,       │
# │       ┆ receive any information on   ┆ "receive", "any", "use",    ┆ -0.036054, -0.007996,       │
# │       ┆ the use of journals i…       ┆ "journals", "any", "type…   ┆ -0.085364, -0.189696, 0.13… │
# │ 5     ┆ my dissertation is an        ┆ ["dissertation", "an",      ┆ [-0.09884, 0.083446,        │
# │       ┆ overview of news databases   ┆ "overview", "news", "at",   ┆ 0.023006, 0.024284,         │
# │       ┆ looking at the availa…       ┆ "availability", "cont…      ┆ -0.070506, -0.192451,       │
# │       ┆                              ┆                             ┆ 0.12612…                    │
# │ 6     ┆ my dissertation is on        ┆ ["dissertation", "chinese", ┆ [-0.003282, 0.112808,       │
# │       ┆ library outreach for the     ┆ "community", "but", "i",    ┆ -0.066718, -0.006573,       │
# │       ┆ chinese community in sh…     ┆ "would", "be", "i…          ┆ -0.029877, -0.206276, -0.0… │
# │ 7     ┆ i would be pleased to        ┆ ["i", "would", "be",        ┆ [-0.117826, 0.086473,       │
# │       ┆ receive papers on the        ┆ "receive", "papers",        ┆ -0.105795, 0.068128,        │
# │       ┆ security of information in…  ┆ "security", "databanks",    ┆ 0.001245, -0.281532,        │
# │       ┆                              ┆ "or…                        ┆ 0.1194…                     │
# │ 8     ┆ i am interested in the       ┆ ["i", "interested",         ┆ [-0.041371, 0.146016,       │
# │       ┆ professional education of    ┆ "professional",             ┆ 0.001363, 0.017463,         │
# │       ┆ librarians in particu…       ┆ "education", "librarians",  ┆ 0.050096, -0.221196,        │
# │       ┆                              ┆ "partic…                    ┆ 0.14706…                    │
# │ 9     ┆ i am interested in the       ┆ ["i", "interested",         ┆ [-0.075474, 0.071178,       │
# │       ┆ extent to which libraries    ┆ "extent", "which",          ┆ -0.004042, 0.070202,        │
# │       ┆ are charging for serv…       ┆ "services", "this",         ┆ 0.009056, -0.194348,        │
# │       ┆                              ┆ "public", "…                ┆ 0.1532…                     │
# │ 10    ┆ i am interested in           ┆ ["i", "interested",         ┆ [-0.029628, 0.08764,        │
# │       ┆ information on the provision ┆ "provision", "current",     ┆ 0.03415, -0.026548,         │
# │       ┆ of current awareness b…      ┆ "awareness", "especially",… ┆ -0.069004, -0.183015,       │
# │       ┆                              ┆                             ┆ 0.07879…                    │
# └───────┴──────────────────────────────┴─────────────────────────────┴─────────────────────────────┘

# %% [markdown]
# # Step 7: Calculate Cosine Similarity

# %%
def cosine_similarity(vec1: np.ndarray, vec2: np.ndarray) -> float:
    norm1 = norm(vec1)
    norm2 = norm(vec2)
    if norm1 == 0 or norm2 == 0:
        return 0.0
    return np.dot(vec1, vec2) / (norm1 * norm2)

# %%
def get_top_k_similar_documents_df(documents: pl.DataFrame, queries: pl.DataFrame, k: int = 5) -> pl.DataFrame:
    document_vectors = documents["avg_vector"].to_list()
    document_indices = documents["index"].to_list()

    top_docs_list = []
    query_ids = []

    for q_idx, query_vec in enumerate(queries["avg_vector"].to_list()):
        similarities = []
        for doc_idx, doc_vec in zip(document_indices, document_vectors):
            sim = cosine_similarity(query_vec, doc_vec)
            similarities.append((doc_idx, sim))

        similarities.sort(key=lambda x: x[1], reverse=True)
        top_k_indices = [int(doc_idx) for doc_idx, _ in similarities[:k]]

        query_ids.append(q_idx + 1)
        top_docs_list.append(top_k_indices)

    result = pl.DataFrame({
        "query_id": query_ids,
        "top_docs": top_docs_list
    })

    return result

# %%
result = get_top_k_similar_documents_df(documents, queries, k=40)

# %%
result.head(10)
# Out:
# shape: (10, 2)
# ┌──────────┬────────────────────────────────────────────────────────────────┐
# │ query_id ┆ top_docs                                                       │
# │ ---      ┆ ---                                                            │
# │ i64      ┆ list[i64]                                                      │
# ╞══════════╪════════════════════════════════════════════════════════════════╡
# │ 1        ┆ [3512, 1444, 1992, 5647, 3279, 5648, 948, 1929, 1445, … 3002]  │
# │ 2        ┆ [585, 5699, 924, 2104, 1104, 3628, 1153, 5090, 765, … 704]     │
# │ 3        ┆ [433, 877, 408, 1431, 1749, 1480, 2933, 3897, 885, … 1406]     │
# │ 4        ┆ [1104, 5250, 5795, 1305, 5090, 6157, 124, 3076, 6347, … 4985]  │
# │ 5        ┆ [3212, 17, 3481, 997, 743, 2954, 5598, 3401, 775, … 3134]      │
# │ 6        ┆ [3589, 568, 5584, 2616, 77, 2671, 1815, 779, 2615, … 664]      │
# │ 7        ┆ [5720, 1272, 2445, 894, 1888, 3267, 5327, 819, 2421, … 1924]   │
# │ 8        ┆ [78, 6046, 3716, 1525, 4063, 4563, 5, 587, 4478, … 40]         │
# │ 9        ┆ [5250, 2579, 3076, 1693, 1651, 5402, 2601, 3792, 1721, … 2324] │
# │ 10       ┆ [3605, 1217, 246, 5527, 5240, 3701, 5249, 5261, 5305, … 2258]  │
# └──────────┴────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # Step 8: Calculate Measurements

# %%
def calculate_measurements(result, real_result, k = 10):
    precisions = []
    recalls = []
    f_measures = []

    for i in range(len(real_result)):
        query_id = real_result[i, "index"]
        relevant = set(real_result[i, "references"])
        retrieved = set(result[i, "top_docs"][:k])

        true_positives = len(relevant & retrieved)
        precision = true_positives / k
        recall = true_positives / len(relevant)

        if precision + recall > 0:
            f1 = 2 * (precision * recall) / (precision + recall)
        else:
            f1 = 0.0

        precisions.append(precision)
        recalls.append(recall)
        f_measures.append(f1)

    pk = sum(precisions) / len(precisions)
    rk = sum(recalls) / len(recalls)
    fk = sum(f_measures) / len(f_measures)

    return pk, rk, fk

# %%
k = 10
pk, rk, fk = calculate_measurements(result, real_result, k)

# %%
print(f"P@{k}: {pk*100:.4f}")
print(f"R@{k}: {rk*100:.4f}")
print(f"F1@{k}: {fk*100:.4f}")
# Out:
# P@10: 7.1429
# R@10: 7.4044
# F1@10: 5.4531

# %% [markdown]
# # Step 9: Show measurements with plot

# %%
ks = list(range(1, 41))
pks, rks, fks = [], [], []

for k in ks:
    pk, rk, fk = calculate_measurements(result, real_result, k)
    pks.append(pk * 100)
    rks.append(rk * 100)
    fks.append(fk * 100)

plt.figure(figsize=(10, 6))
plt.plot(ks, pks, label='Precision@k', color='purple')
plt.plot(ks, rks, label='Recall@k', color='orange')
plt.plot(ks, fks, label='F1@k', color='blue')

plt.title('Precision, Recall, and F1 Score over different k values')
plt.xlabel('k')
plt.ylabel('Percentage (%)')
plt.xticks(range(0, 41, 5))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
